# %%
# imports
from contextlib import closing
import sqlite3
import re
from dateutil import parser as date_parser

# %%
# testing

db_path = "../../data/vatican_texts.db"

# %%
def load_popes_only(db_path):
    """
    Returns all popes from the provided database
    """
    with closing(sqlite3.connect(database=db_path)) as connection:
        with connection:
            connection.row_factory = sqlite3.Row
            
            query_results = connection.execute("SELECT pope_name, pope_number, place_of_birth, _pope_id FROM popes")

            popes = [{
                'pope_name': row["pope_name"],
                'pope_number': row["pope_number"],
                'place_of_birth': row['place_of_birth'],
                'pope_id': row['_pope_id']
            } for row in query_results]
            # popes = [
            #     {
            #         'pope_name': row['pope_name'],
            #         'pope_data': {k:row[k] for k in row.keys() if k != 'pope_name'}
            #     }
            # for row in rows]
    return popes

popes = load_popes_only(db_path)

# %%
popes
# Out:
# [{'pope_name': 'Benedict XVI',
#   'pope_number': '265th Pope of the Catholic Church',
#   'place_of_birth': 'Marktl, Germany',
#   'pope_id': 1},
#  {'pope_name': 'John Paul II',
#   'pope_number': '264th Pope of the Catholic Church',
#   'place_of_birth': 'Wadowice, Poland',
#   'pope_id': 2},
#  {'pope_name': 'Paul VI',
#   'pope_number': '262nd Pope of the Catholic Church',
#   'place_of_birth': 'Concesio, Italy',
#   'pope_id': 3},
#  {'pope_name': 'Francis',
#   'pope_number': '266th Pope of the Catholic Church',
#   'place_of_birth': 'Buenos Aires, Argentina',
#   'pope_id': 4},
#  {'pope_name': 'Leo XIV',
#   'pope_number': '267th Pope of the Catholic Church',
#   'place_of_birth': 'Chicago, Illinois',
#   'pope_id': 5}]

# %%
def load_speeches_only(db_path, popes):
    pope_data = {}
    with closing(sqlite3.connect(db_path)) as connection:
        with connection:
            connection.row_factory = sqlite3.Row
            for pontiff in popes:
                query_results = connection.execute(
                    """
                    SELECT title, date, section
                    FROM texts
                    WHERE pope_id = ?
                    ORDER by date
                    """,
                    (pontiff['pope_id'],)
                )
                pontiff_text_data = [
                    {
                        'title': qr['title'],
                        'date': qr['date'],
                        'category': qr['section']
                    }
                    for qr in query_results
                ]
                pope_data[pontiff['pope_name']] = pontiff_text_data
    return pope_data

load_speeches_only(db_path, popes)
# Out:
# {'Benedict XVI': [{'title': 'To the members of the Vatican City State Police Force (December 31, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Visit to the Pontifical Dispensary of "Santa Marta" (December 30, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the participants of the International Congress of the Pueri Cantores (December 30, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the employees who renovated the Private Apartments in the Vatican Apostolic Palace (December 23, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Ambassador of the United Kingdom of Great Britain and Northern Ireland to the Holy See (December 23, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Christmas greetings to the Members of the Roman Curia and Prelature (December 22, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the singers of the Pontifical Musical Chorus of the "Sistine" (December 20, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the young men and women of Italian Catholic Action (December 19, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Ambassador of France to the Holy See (December 19, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': "To the Pilgrims of Upper Austria on the occasion of the donation of the Christmas tree in Saint Peter's Square (December 17, 2005)",
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the third group of Bishops of the Polish Episcopal Conference on occasion of their ad Limina visit (December 17, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the representatives of the Italian Armed  Forces (December 16, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Greeting at the conclusion of Advent Mass for the students of Roman Universities (December 15, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the members of the Joint International Commission for Theological Dialogue Between the Catholic Church and the Orthodox Church (December 15, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Men and Women Religious, members of Secular Institutes and Societies of Apostolic Life of the Rome Diocese (December 10, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To representatives of the World Methodist Council (December 9, 2005)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': '
 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the newly created Cardinals, their family members and pilgrims present at the Consistory (November 26, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'At the conclusion of the Ordinary Public Consistory for the creation of 23 new Cardinals (November 24, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To participants in the Thirty-fourth Conference of the Food and Agriculture Organization of the United Nations (November 22, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To members of the Episcopal Conference of Kenya on their ad Limina visit (November 19, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To participants in the 22nd International Conference organized by the Pontifical Council for Health Pastoral Care on the theme: "The Pastoral Care of the Aged Sick" (November 17, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To participants in the meeting of Superiors General of Missionary Societies of Apostolic Life sponsored by the Congregation for the Evangelization of Peoples (November 16, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Ambassador of the Republic of Indonesia to the Holy See (November 12, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Confederation of Confraternities from various Dioceses of Italy (November 10, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To members of the Episcopal Conference of Portugal on their ad Limina visit (November 10, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To members of the Italian Catholic University Federation (F.U.C.I.) (November 9, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To participants in the International Meeting of The New Families Movement sponsored by the Focolare Movement (November 3, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the participants in the 25th International Congress of Catholic Pharmacists (October 29, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Address at the conclusion of the concert offered by the Symphonic Orchestra and Choir of Bavarian Radio (October 27, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the new Ambassador of the Republic of Ecuador to the Holy See (October 27, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Bishops of the Episcopal Conference of the Republic of Gabon on their ad Limina visit (October 26, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Students of the Pontifical Universities of Rome at the beginning of the Academic Year (October 25, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Pastoral Visit to Naples: Luncheon address to the Cardinals, the Bishops of Campania, and the participants in the International Encounter for Peace (October 21, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Pastoral Visit to Naples: Greeting to the Heads of Delegations taking part in the International Encounter for Peace at the Episcopal Seminary of Capodimonte (October 21, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To members of the Delegation of the "Mennonite World Conference" (October 19, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'To the Bishops of the Episcopal Conference of the Republic of the Congo on their ad Limina visit (October 19, 2007)',
#    'date': None,
#    'category': 'speeches'},
#   {'title': 'Visit to the Pontifical Institute for Sacred Music (October 13, 2007)',
#    'date': None,
# ...
#    'category': 'speeches'},
#   {'title': 'To the Members of the International Youth Advisory Body (31 October 2025)',
#    'date': '31 October 2025',
#    'category': 'speeches'},
#   {'title': 'To the Members of the Organisation of Catholic Universities of Latin America and the Caribbean (ODUCAL) (31 October 2025)',
#    'date': '31 October 2025',
#    'category': 'speeches'},
#   {'title': 'To the Delegation of "The National Italian American Foundation" (4 June 2025)',
#    'date': '4 June 2025',
#    'category': 'speeches'},
#   {'title': 'General Audience of 4 June 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. II. The life of Jesus. The parables 8. The labourers in the vineyard. “And he said to them, ‘You too go into my vineyard’”(Mt 20:4)',
#    'date': '4 June 2025',
#    'category': 'audiences'},
#   {'title': 'To the Delegation of "The National Italian American Foundation" (4 June 2025)',
#    'date': '4 June 2025',
#    'category': 'speeches'},
#   {'title': 'General Audience of 4 June 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. II. The life of Jesus. The parables 8. The labourers in the vineyard. “And he said to them, ‘You too go into my vineyard’”(Mt 20:4)',
#    'date': '4 June 2025',
#    'category': 'audiences'},
#   {'title': 'Jubilee Audience - Catechesis. 6. To Hope is to Choose. Clare of Assisi (4 October 2025)',
#    'date': '4 October 2025',
#    'category': 'audiences'},
#   {'title': 'Jubilee Audience - Catechesis. 6. To Hope is to Choose. Clare of Assisi (4 October 2025)',
#    'date': '4 October 2025',
#    'category': 'audiences'},
#   {'title': 'To Organizers and Artists of the Concert with the Poor (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To a Delegation of the “Paris Course on Revascularization” (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the Conference “Artificial Intelligence and Care for Our Common Home” (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To Organizers and Artists of the Concert with the Poor (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To a Delegation of the “Paris Course on Revascularization” (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the Conference “Artificial Intelligence and Care for Our Common Home” (5 December 2025)',
#    'date': '5 December 2025',
#    'category': 'speeches'},
#   {'title': 'To the Augustinian Sisters, Servants of Jesus and Mary (5 July 2025)',
#    'date': '5 July 2025',
#    'category': 'speeches'},
#   {'title': 'To Teachers of Catholic Schools in Ireland, England, Wales, and Scotland; and to the Young People of the Diocese of Copenhagen (5 July 2025)',
#    'date': '5 July 2025',
#    'category': 'speeches'},
#   {'title': 'To the Augustinian Sisters, Servants of Jesus and Mary (5 July 2025)',
#    'date': '5 July 2025',
#    'category': 'speeches'},
#   {'title': 'To Teachers of Catholic Schools in Ireland, England, Wales, and Scotland; and to the Young People of the Diocese of Copenhagen (5 July 2025)',
#    'date': '5 July 2025',
#    'category': 'speeches'},
#   {'title': 'To Superiors and Officials of the Secretariat of State (5 June 2025)',
#    'date': '5 June 2025',
#    'category': 'speeches'},
#   {'title': 'To Superiors and Officials of the Secretariat of State (5 June 2025)',
#    'date': '5 June 2025',
#    'category': 'speeches'},
#   {'title': 'General Audience of 5 November 2025 - Cycle of Catechesis – Jubilee 2025: Jesus Christ our hope. 4. The Resurrection of Christ and the challenges of the contemporary world. 3. Easter gives hope to everyday life',
#    'date': '5 November 2025',
#    'category': 'audiences'},
#   {'title': 'General Audience of 5 November 2025 - Cycle of Catechesis – Jubilee 2025: Jesus Christ our hope. 4. The Resurrection of Christ and the challenges of the contemporary world. 3. Easter gives hope to everyday life',
#    'date': '5 November 2025',
#    'category': 'audiences'},
#   {'title': 'Holy Mass - Jubilee of the Missionary World and Jubilee of Migrants (5 October 2025)',
#    'date': '5 October 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass - Jubilee of the Missionary World and Jubilee of Migrants (5 October 2025)',
#    'date': '5 October 2025',
#    'category': 'homilies'},
#   {'title': 'To the Mediterranean Youth Council (5 September 2025)',
#    'date': '5 September 2025',
#    'category': 'speeches'},
#   {'title': "Inauguration and blessing of the Borgo Laudato si' (Castel Gandolfo, 5 September 2025)",
#    'date': '5 September 2025',
#    'category': 'homilies'},
#   {'title': 'To the Mediterranean Youth Council (5 September 2025)',
#    'date': '5 September 2025',
#    'category': 'speeches'},
#   {'title': "Inauguration and blessing of the Borgo Laudato si' (Castel Gandolfo, 5 September 2025)",
#    'date': '5 September 2025',
#    'category': 'homilies'},
#   {'title': 'General Audience of 6 August 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. III. The Passover of Jesus. 1. The preparation of the supper. “Make the preparations for us there” (Mk 14:15)',
#    'date': '6 August 2025',
#    'category': 'audiences'},
#   {'title': 'General Audience of 6 August 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. III. The Passover of Jesus. 1. The preparation of the supper. “Make the preparations for us there” (Mk 14:15)',
#    'date': '6 August 2025',
#    'category': 'audiences'},
#   {'title': 'Concert with the Poor (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'speeches'},
#   {'title': 'Presentation of Credential Letters by the Ambassadors of Uzbekistan, Moldova, Bahrein, Sri Lanka, Pakistan, Liberia, Thailand, Lesotho, South Africa, Fiji, Micronesia, Latvia and Finland (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee Audience - Catechesis. 10. To hope is to participate – Alberto Marvelli (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'audiences'},
#   {'title': 'Concert with the Poor (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'speeches'},
#   {'title': 'Presentation of Credential Letters by the Ambassadors of Uzbekistan, Moldova, Bahrein, Sri Lanka, Pakistan, Liberia, Thailand, Lesotho, South Africa, Fiji, Micronesia, Latvia and Finland (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee Audience - Catechesis. 10. To hope is to participate – Alberto Marvelli (6 December 2025)',
#    'date': '6 December 2025',
#    'category': 'audiences'},
#   {'title': 'Solemnity of the Epiphany of the Lord  – Closing of the Holy Door and Holy Mass (6 January 2025)',
#    'date': '6 January 2025',
#    'category': 'homilies'},
#   {'title': 'Solemnity of the Epiphany of the Lord  – Closing of the Holy Door and Holy Mass (6 January 2025)',
#    'date': '6 January 2025',
#    'category': 'homilies'},
#   {'title': 'To the Moderators of Lay Associations, Ecclesial Movements and New Communities (6 June 2025)',
#    'date': '6 June 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the General Chapters of the Society of African Missions, of the third Order Regular of St Francis, of the Formators of the Servants of the Paraclete (6 June 2025)',
#    'date': '6 June 2025',
#    'category': 'speeches'},
#   {'title': 'To the Moderators of Lay Associations, Ecclesial Movements and New Communities (6 June 2025)',
#    'date': '6 June 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the General Chapters of the Society of African Missions, of the third Order Regular of St Francis, of the Formators of the Servants of the Paraclete (6 June 2025)',
#    'date': '6 June 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the General Chapters of the Religious of Jesus and Mary and of the Missionary Sisters of St. Charles Borromeo (Scalabrinians) (6 November 2025)',
#    'date': '6 November 2025',
#    'category': 'speeches'},
#   {'title': "To Members of the Joint Committee of the Council of European Bishops' Conferences (CCEE), the Conference of European Churches (CEC), and Representatives of the Christian Churches of Europe (6 November 2025)",
#    'date': '6 November 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the General Chapters of the Religious of Jesus and Mary and of the Missionary Sisters of St. Charles Borromeo (Scalabrinians) (6 November 2025)',
#    'date': '6 November 2025',
#    'category': 'speeches'},
#   {'title': "To Members of the Joint Committee of the Council of European Bishops' Conferences (CCEE), the Conference of European Churches (CEC), and Representatives of the Christian Churches of Europe (6 November 2025)",
#    'date': '6 November 2025',
#    'category': 'speeches'},
#   {'title': 'Celebration of Vespers (Domus Australia, 6 October 2025)',
#    'date': '6 October 2025',
#    'category': 'homilies'},
#   {'title': 'Celebration of Vespers (Domus Australia, 6 October 2025)',
#    'date': '6 October 2025',
#    'category': 'homilies'},
#   {'title': 'To Participants in the Mariological Marian International Congress (6 September 2025)',
#    'date': '6 September 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee Audience - Catechesis. 4. To hope is to dig. Empress Helena (6 September 2025)',
#    'date': '6 September 2025',
#    'category': 'audiences'},
#   {'title': 'To Participants in the Mariological Marian International Congress (6 September 2025)',
#    'date': '6 September 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee Audience - Catechesis. 4. To hope is to dig. Empress Helena (6 September 2025)',
#    'date': '6 September 2025',
#    'category': 'audiences'},
#   {'title': 'Extraordinary Consistory (7 January 2026)',
#    'date': '7 January 2026',
#    'category': 'speeches'},
#   {'title': 'General Audience of 7 January 2026 - Catechesis. Vatican Council II through its Documents. Introductory catechesis',
#    'date': '7 January 2026',
#    'category': 'audiences'},
#   {'title': 'Extraordinary Consistory (7 January 2026)',
#    'date': '7 January 2026',
#    'category': 'speeches'},
#   {'title': 'General Audience of 7 January 2026 - Catechesis. Vatican Council II through its Documents. Introductory catechesis',
#    'date': '7 January 2026',
#    'category': 'audiences'},
#   {'title': 'To participants in the Ecumenical Symposium on the occasion of the 1700th Anniversary of the Council of Nicaea (7 June 2025)',
#    'date': '7 June 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee of Ecclesial Movements - Vigil of Pentecost (7 June 2025)',
#    'date': '7 June 2025',
#    'category': 'homilies'},
#   {'title': 'To participants in the Ecumenical Symposium on the occasion of the 1700th Anniversary of the Council of Nicaea (7 June 2025)',
#    'date': '7 June 2025',
#    'category': 'speeches'},
#   {'title': 'Jubilee of Ecclesial Movements - Vigil of Pentecost (7 June 2025)',
#    'date': '7 June 2025',
#    'category': 'homilies'},
#   {'title': 'To Participants in the General Assembly of the Italian Conference of Major Superiors (CISM) (7 November 2025)',
#    'date': '7 November 2025',
#    'category': 'speeches'},
#   {'title': 'To Members of the Fondation Internationale Religions et Sociétés (7 November 2025)',
#    'date': '7 November 2025',
#    'category': 'speeches'},
#   {'title': 'To Participants in the General Assembly of the Italian Conference of Major Superiors (CISM) (7 November 2025)',
#    'date': '7 November 2025',
#    'category': 'speeches'},
#   {'title': 'To Members of the Fondation Internationale Religions et Sociétés (7 November 2025)',
#    'date': '7 November 2025',
#    'category': 'speeches'},
#   {'title': 'Holy Mass with Canonizations (7 September 2025)',
#    'date': '7 September 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass with Canonizations (7 September 2025)',
#    'date': '7 September 2025',
#    'category': 'homilies'},
#   {'title': 'Conclusion of the Extraordinary Consistory (8 January 2026)',
#    'date': '8 January 2026',
#    'category': 'speeches'},
#   {'title': 'Weekday of the Christmas Season: Extraordinary Consistory – Holy Mass (8 January 2026)',
#    'date': '8 January 2026',
#    'category': 'homilies'},
#   {'title': 'Conclusion of the Extraordinary Consistory (8 January 2026)',
#    'date': '8 January 2026',
#    'category': 'speeches'},
#   {'title': 'Weekday of the Christmas Season: Extraordinary Consistory – Holy Mass (8 January 2026)',
#    'date': '8 January 2026',
#    'category': 'homilies'},
#   {'title': 'Pentecost Sunday - Holy Mass in the Jubilee of Movements, Associations and New Communities (8 June 2025)',
#    'date': '8 June 2025',
#    'category': 'homilies'},
#   {'title': 'Pentecost Sunday - Holy Mass in the Jubilee of Movements, Associations and New Communities (8 June 2025)',
#    'date': '8 June 2025',
#    'category': 'homilies'},
#   {'title': 'Jubilee Audience - Catechesis. 8. To hope is to bear witness. Isidore Bakanja (8 November 2025)',
#    'date': '8 November 2025',
#    'category': 'audiences'},
#   {'title': 'Jubilee Audience - Catechesis. 8. To hope is to bear witness. Isidore Bakanja (8 November 2025)',
#    'date': '8 November 2025',
#    'category': 'audiences'},
#   {'title': 'General Audience of 8 October 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. 10. Rekindling. “Were not our hearts burning within us?” (Lk 24:32)',
#    'date': '8 October 2025',
#    'category': 'audiences'},
#   {'title': 'General Audience of 8 October 2025 - Cycle of Catechesis – Jubilee 2025. Jesus Christ our Hope. 10. Rekindling. “Were not our hearts burning within us?” (Lk 24:32)',
#    'date': '8 October 2025',
#    'category': 'audiences'},
#   {'title': 'To members of the Diplomatic Corps accredited to the Holy See (9 January 2026)',
#    'date': '9 January 2026',
#    'category': 'speeches'},
#   {'title': 'To members of the Diplomatic Corps accredited to the Holy See (9 January 2026)',
#    'date': '9 January 2026',
#    'category': 'speeches'},
#   {'title': 'Holy Mass for the Care of Creation (9 July 2025)',
#    'date': '9 July 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass for the Care of Creation (9 July 2025)',
#    'date': '9 July 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass for the Jubilee of the Holy See (9 June 2025)',
#    'date': '9 June 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass for the Jubilee of the Holy See (9 June 2025)',
#    'date': '9 June 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass pro Ecclesia celebrated by the Roman Pontiff Leo XIV with the Cardinals (9 May 2025)',
#    'date': '9 May 2025',
#    'category': 'homilies'},
#   {'title': 'Holy Mass pro Ecclesia celebrated by the Roman Pontiff Leo XIV with the Cardinals (9 May 2025)',
#    'date': '9 May 2025',
#    'category': 'homilies'},
#   {'title': 'Feast of the Dedication of the Basilica of St John Lateran - Holy Mass (9 November 2025)',
#    'date': '9 November 2025',
#    'category': 'homilies'},
#   {'title': 'Feast of the Dedication of the Basilica of St John Lateran - Holy Mass (9 November 2025)',
#    'date': '9 November 2025',
#    'category': 'homilies'},
#   {'title': 'To Participants in the MINDS International Association Conference (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'speeches'},
#   {'title': 'Greeting of His Holiness Pope Leo XIV to Labor Leaders from Chicago (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'speeches'},
#   {'title': 'Holy Mass - Jubilee of Consecrated Life (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'homilies'},
#   {'title': 'To Participants in the MINDS International Association Conference (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'speeches'},
#   {'title': 'Greeting of His Holiness Pope Leo XIV to Labor Leaders from Chicago (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'speeches'},
#   {'title': 'Holy Mass - Jubilee of Consecrated Life (9 October 2025)',
#    'date': '9 October 2025',
#    'category': 'homilies'}]}

# %%
# Entries without dates often have it in the title, as such: Title So and So (DATE). So this helps us extract it from.

def extract_date_from_title(sentence:str):
    """
    obtains the date from the end of a sentence.
    Supports: (Month DD, YYYY) OR (DD Month YYYY) OR (DD[nd, rd, st] Month YYYY)
    """
    # pattern = r"\((?:.*,\s+)?([A-Z][a-z]+ \d{1,2}, \d{4}|\d{1,2}(?:st|nd|rd|th)? [A-Z][a-z]+ \d{4})\)$"
    pattern = r"""
        \(                # Opening parenthesis
        (?:.*,\s+)?       # Optional location and comma
        (                 # Start capture group for date
            [A-Z][a-z]+\s+\d{1,2},\s+\d{4}     # Month DD, YYYY
            |                                  # OR
            \d{1,2}(?:st|nd|rd|th)?\s+[A-Z][a-z]+\s+\d{4} # DD Month YYYY
        )                 # End capture group
        \)                # Closing parenthesis
        $                 # End of line
    """
    match = re.search(pattern, sentence.strip(), re.IGNORECASE | re.VERBOSE)
    if match:
        return match.group(1)  # Returns the content inside the parentheses
    return None

# test
t1 = extract_date_from_title('To the members of the Vatican City State Police Force (December 31, 2005)')
t2 = extract_date_from_title('(10 december 2025)')
t3 = extract_date_from_title('(1st June 2025)')
t4 = extract_date_from_title('(Castel Gandolfo, 1st October 2025)')
print(t1,t2,t3,t4)
# Out:
# December 31, 2005 10 december 2025 1st June 2025 1st October 2025

# %%
def clean_papacy_date(date_old_format:str):
    """
    Converting from the following format: DD,HH.MMM.YYYY, but months are in roman
    """
    roman_map = {
        'I':'01', 'II':'02', 'III':'03', 'IV':'04', 'V':'05', 'VI':'06',
        'VII':'07', 'VIII':'08', 'IX':'09', 'X':'10', 'XI':'11', 'XII':'12'
    }
    temp = date_old_format.split(',')
    day = temp[0]
    if len(day) == 1:
        day = '0' + day
    month, year = temp[1].split('.')[1:]
    month = roman_map[month]
    new_date = f"{year}-{month}-{day}"
    return new_date

# %%
def clean_text_date(date:str):
    """
    Turns date from a given format to YYYY-MM-DD
    Supports: (Month DD, YYYY) OR (DD Month YYYY) OR (DD[nd, rd, st] Month YYYY)
    """
    # STEP 0 - date is non
    if date is None:
        return date
    # STEP 1 - Try parser
    try:
        new_date = date_parser.parse(date, fuzzy=True)
        return new_date.strftime("%Y-%m-%d")
    except (date_parser.ParserError) as e:
        # print(f"Parser didn't help, trying manually. Error: {e}")
        pass
    
    # STEP 2 - try manually
    parts = date.split(' ')
    discard_symbols = [',', 'st', 'nd', 'rd', 'th']
    for symbol in discard_symbols:
        parts = [p.replace(symbol, '') for p in parts]
    year = parts[2]
    try:
        day = int(parts[0])
        month = parts[1]
    except ValueError:
        month = parts[0]
        day = int(parts[1])
    day = str(day)
    if len(day) == 1:
        day = '0' + day
    
    # clean month
    month_map = {
        "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04",
        "maggio": "05", "giugno": "06", "luglio": "07", "agosto": "08",
        "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
    }
    try:
        month = int(month)
    except ValueError:
        # convert from word to number
        month = month_map.get(month, month)

    new_date = f"{year}-{month}-{day}"
    return new_date

with open('test_dates.txt', 'r') as f:
    test_dates = f.readlines()

for dt in test_dates:
    print(clean_text_date(dt))
# Out:
# 2005-12-31
# 2025-12-10
# 2025-06-01
# 2025-10-01
# 1985-04-01
# 2018-04-01

# %%
def load_speeches_join_pope(db_path):
    """
    popes_data is a dict that looks like this:
    {
        "<pope_name>": {"pope_name": str,
                        "papacy_began": str,
                        "texts": [{ "title": str,
                                    "date": str | date,
                                    "category": str}, ...]
        },...}
    """
    with closing(sqlite3.connect(db_path)) as connection:
        with connection:
            connection.row_factory = sqlite3.Row
            query = (
                """
                SELECT p.pope_name, t.title, t.date, t.section, p.pontificate_begin
                FROM popes p
                JOIN texts t ON p._pope_id = t.pope_id
                ORDER BY p.pontificate_begin, t.date
                """
            )

            query_results =  connection.execute(query)
            popes_data = {}

            for row in query_results:
                pope_name = row['pope_name']
                if pope_name not in popes_data:
                    popes_data[pope_name] = {
                        'pope_name': pope_name,
                        'papacy_began': clean_papacy_date(row['pontificate_begin']),
                        'texts': []
                    }
                # reformat dates
                if row['date'] is not None:
                    new_date = clean_text_date(row['date'])
                else:
                    new_date = extract_date_from_title(row['title'])
                    new_date = clean_text_date(new_date)
                popes_data[pope_name]['texts'].append({
                    'title': row["title"],
                    'date': new_date,
                    'category': row['section']
                })

    return popes_data

popes_data = load_speeches_join_pope(db_path)

# %%
def rearrange_pope_data(popes_data):
    for pdata in popes_data.values():

        pdata['texts'].sort(key=lambda x: (x['date'] is None, x['date']))
    return popes_data

popes_data = rearrange_pope_data(popes_data)

# %%
# This was me just visualizing the resulting dates better
with open('reformatted_dates.txt', 'w') as f:
    for pontiff, pontiff_data in popes_data.items():
        f.write(f"<<{pontiff}>>:\n\n")
        for text in pontiff_data['texts']:
            if text['date']:
                f.write(text['date'] + '\n')
            else:
                f.write('NONE FOUND\n')
        f.write('\n\n\n')

# %% [markdown]
# OK great, almost there, maybe one last thing would be to take all dates that are valid (get rid of nones, and other stragglers), and use those for our stats.
# * Note: there are some not nones that are just randome other languages or possibly typos: jaunary(?), octobre (french), etc.

# %%
def print_pope_data(popes_data):
    for _, pdata in popes_data.items():
        pope_stats = f"""{pdata['pope_name']}:\nNumber of texts: {len(pdata['texts'])}.\nPapacy began: {pdata['papacy_began']}\n"""
        print(pope_stats)
    return

print_pope_data(popes_data)
# Out:
# Francis:
# Number of texts: 4619.
# Papacy began: 2013-03-13
#
# John Paul II:
# Number of texts: 2719.
# Papacy began: 1978-10-16
#
# Benedict XVI:
# Number of texts: 2932.
# Papacy began: 2005-04-19
#
# Paul VI:
# Number of texts: 541.
# Papacy began: 1963-06-21
#
# Leo XIV:
# Number of texts: 520.
# Papacy began: 2025-05-08

# %%
popes_data['Francis']['texts'][1]
# Out:
# {'title': 'Address to participants in the International Seminar on the Pope\'s proposal made in Evangelii Gaudium "Towards a more inclusive economy"',
#  'date': None,
#  'category': 'speeches'}
